# %%
import import_ipynb
import unittest
target = __import__("my_sum.ipynb")
aaa = target.__init__

class TestSum(unittest.TestCase):
    
    def test_sum(self):
        data = [1, 2, 3]
        result = aaa.sums_iterable(data)
        self.assertEqual(result, 6)
        
if __name__=='__main__':
    unittest.main()
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# <ipython-input-5-53ddb12048c9> in <module>
#       1 import import_ipynb
#       2 import unittest
# ----> 3 target = __import__("my_sum.ipynb")
#       4 aaa = target.__init__
#       5
#
# ModuleNotFoundError: No module named 'my_sum.ipynb'
