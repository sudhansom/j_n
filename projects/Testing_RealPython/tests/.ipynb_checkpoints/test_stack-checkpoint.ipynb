# %%
from program.stack import Stack

def test_constructor():
    s = Stack()
    assert isinstance(s, Stack)
    assert len(s) == 0
# Out:
# ----------------------------------------------------------------------
# ModuleNotFoundError                  Traceback (most recent call last)
# <ipython-input-7-c8cda9d0b72a> in <module>
# ----> 1 from program import Stack
#       2
#       3 def test_constructor():
#       4     s = Stack()
#       5     assert isinstance(s, Stack)
#
# ModuleNotFoundError: No module named 'program'
